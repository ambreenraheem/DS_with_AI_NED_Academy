# %% [markdown]
# # **def function**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# function
def message():            # def is a function ans message is the name of that function
    print("I like python coding.")   # 
# function calling means call the function using its name
message()
# Out:
# I like python coding.

# %%
def name ():           # function with the name of (name)
    print("Ambreen")
name()                 # function calling with it's name (name)

def husband():         # function with the name of (husband)
    print("Abdul Raaheem")
husband()               # function calling with it's name (husband)

def father():           # function with the name of (father)
    print("Ashique Hussain")
father()                # function calling with it's name (father)
# Out:
# Ambreen
# Abdul Raaheem
# Ashique Hussain

# %%
def square():
    print(2**2)
square()

def add():
    print(34+56)
add()

def sub():
    print(456-345)
sub()

def product():
    print(3056*23)
product()

# yhan sb samne aenge
# Out:
# 4
# 90
# 111
# 70288

# %%
# function to find square of a number
def square():
    # """document string"""
    """
    This function is used for only square
    """
    x = 9**2        # expression
    return x        # statement ko print kro return kr k
square()
# Out:
# 81

# %%
# def function2
def add2():
    """ Ye function return k sath mathematics krta he print function ki zrort nai prti"""
    y= 56+6
    return y    # return ek statement he. return kryn ya print kryn        
add2()
# Out:
# 62

# %%
def name ():
    return "Ambreem"          # it is working with return as well as a print
name()

def name3():
    return 'Snija'
name3()      # jo last m he whi output aega
# Out:
# 'Snija'

# %% [markdown]
# Taking 'even' and 'odd' number in function

# %%
def check_even(num):   # it is parameter in the prenthesis of the function
   if num % 2 == 0:
       return "even"
   else:
       return "odd"
check_even(5)  # putting input in the calling of function / type input inside the prenthesis of argument
# Out:
# 'odd'

# %%
def check_even(num):
   if num % 2 == 0:
       return "even"
   else:
       return "odd"
check_even(70)  # taking input/ type input inside the prenthesis of argument
# Out:
# 'even'

# %% [markdown]
# #### We need to define our parameter then we can be able to set our argument.
# If user is putting string in argument then he/she should get any instrustion from the function:\
# for help always define your function in doc function.\
# The best benefit of the function is you can use it many time in different condition on same cell or program

# %% [markdown]
# ### It is define function that's why it is working

# %%
def check_even(num):
    """
    This function returns if a given number is odd or even.
    input - any valid integer
    output - odd/even
    if input - string
    output - Enter valid Number
    created on 29th August 2024
    """
    if type(num) == int:
    
       if num % 2 == 0:
         return "even"
       else:
         return "odd"
    else:
      return "Enter valid Number"  # it is define function that's why it is working

# %%
# calling of function with print
print(check_even("rhkun34"))
print(check_even(7))
print(check_even(8))
# Out:
# Enter valid Number
# odd
# even

# %% [markdown]
# How can the user see doc function\
# for the help of the user document function just code this\
# agr likha hoga to aega output

# %%
print(check_even.__doc__)
# Out:
#     This function returns if a given number is odd or even.
#     input - any valid integer
#     output - odd/even
#     created on 29th August 2024

# %% [markdown]
# ### It is not define becuause argument is not string

# %%
def check_even(num):
   if num % 2 == 0:
       return "even"
   else:
       return "odd"
check_even("hello")        # it is not define becuause argument is not string

# %% [markdown]
# Taking cube of any number

# %%
number= int(input("Enter a number")) # with user input
def cube():
    x = number**3
    return x
cube()             # both parameter and argument are empty but if you want to put any one then put it in beginning
# Out:
# 512

# %%
name1= str(input("Enter your first name:\t"))
name2 = str(input("Enter last name"))
def my_function(name1, name2):
    print(name1 + " " + name2)
my_function(name1,name2)
# Out:
# Ali Ahmad

# %%
def is_prime(number):
    if number < 2:
        return False
    for i in range(2, int(number**0.5)+1):
        if number % i == 0:
            return False
    return True

# %%
# Calling function
is_prime(7)
# Out:
# True

# %% [markdown]
# default argument rehta he.

# %%
def power(a=1,b=1): # inputs
    return a**b           # 
power(2,4)        # positional argument
# Out:
# 16

# %%
# positional argument
def name(Fname='Ambreen', Lname='Abdulraheem'):
    return Fname+ " "+Lname
name()
# Out:
# 'Ambreen Abdulraheem'

# %% [markdown]
# *args and **kwargs

# %%
def product(a,b,c):
    return a*b*c
product(2,3,4)
# Out:
# 24

# %%
def multiply(*args):
    product = 1
    for i in args:
        product = product * i
    print(args)
    return product
multiply()
# Out:
# ()
# 1

# %%
def userDetail(args):
    print(args)
fullname= input("Enter your name")
profession= input("Enter your profession")
gender= input("Enter your gender")
age= input("enter your age")
specialization= input("enter your specialization")
userDetail(fullname,profession,gender,age,specialization) # ye dorakrna he

# %%
def sum_of_list(*args):
    sum_num=[0]
    for num in args:
        sum_num = sum(num)
        print(sum_num)
        return sum_num

# %%
# calling function
num=[4,5,6]
sum_of_list(num)
# Out:
# 15
# 15
